# %%
import pandas as pd
from matplotlib import pyplot as plt
% matplotlib inline

# %%
tweets = pd.read_csv('pol-tweets_janjul2020_subset.csv')

# %%
type(tweets)
# Out:
# pandas.core.frame.DataFrame

# %%
tweets.head() # method
# Out:
#                     id            name       username        date  \
# 0  1276394982811807745  Josephine Fock  josephinefock  2020-06-26
# 1  1276116154793295873  Josephine Fock  josephinefock  2020-06-25
# 2  1275714928343728128  Josephine Fock  josephinefock  2020-06-24
# 3  1274847089961336836  Josephine Fock  josephinefock  2020-06-22
# 4  1273948042475995138  Josephine Fock  josephinefock  2020-06-19
#
#                  hashtags                                              tweet
# 0              ['#dkpol']  Hvorfor går man ikke i dialog med ⁦@DRC_dk⁩ i ...
# 1                      []  Alle tæller ❤️ https://twitter.com/cekicozlem/...
# 2                      []  Det er så godt arbejde💚 https://twitter.com/fa...
# 3  ['#dkpol', '#dkgreen']  Tilfreds med den klima og energiaftale, der er...
# 4  ['#dkpol', '#dkgreen']  Godt første skridt for den fri natur #dkpol #d...

# %%
tweets.shape # attribute
# Out:
# (8094, 6)

# %%
tweets['name'].value_counts()
# Out:
# Stinus Lindgreen               1328
# Simon Emil Ammitzbøll-Bille    1042
# Pia Olsen Dyhr                  693
# Jakob Ellemann-Jensen           633
# Rasmus Stoklund                 479
# Alex Vanopslagh                 405
# Pernille Skipper                399
# Signe Munk                      389
# Morten Østergaard               354
# Morten Messerschmidt            330
# Mette Abildgaard                323
# Dan Jørgensen                   248
# Søren Pape Poulsen              204
# Mogens Jensen                   178
# Josephine Fock                  162
# Ole Birk Olesen                 159
# Kristian Thulesen Dahl          141
# Torsten Gejl                    127
# Peder Hvelplund                 119
# Ida Auken                       100
# Anne Paulin                      90
# Mai Villadsen                    82
# Lise Bech 🇩🇰 DF                  61
# Tommy Ahlers                     34
# Kim Valentin                     14
# Name: name, dtype: int64

# %%
tweets['name'].value_counts().plot.bar(figsize=(15,15))
# Out:
# C:\Users\kgk\.conda\envs\tm\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127465 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kgk\.conda\envs\tm\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127472 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kgk\.conda\envs\tm\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127465 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\kgk\.conda\envs\tm\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 127472 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
tweets['date'] = pd.to_datetime(tweets_timecount['date'], format='%Y-%m-%d')

# %%
tweets_grouped = tweets.groupby('date')

tweets_grouped.count().plot(y = 'tweet', figsize=(15,15))
# Out:
# <AxesSubplot:xlabel='date'>
